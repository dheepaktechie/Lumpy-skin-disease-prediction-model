# %%
# !nvidia-smi
# Out:
# Sat Feb 22 09:31:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.1/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QWnTUj9I0smYWhEjeb5i")
project = rf.workspace("end-game").project("lumpy-skin-diesease-c09dg")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to lumpy-skin-diesease--1 in yolov11:: 100%|██████████| 686/686 [00:00<00:00, 10006.20it/s]

# %%
dataset.location
# Out:
# '/content/lumpy-skin-diesease--1'

# %%
# !yolo task = detect mode= train data= /content/lumpy-skin-diesease--1/data.yaml model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 321MB/s]
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !gdown "https://drive.google.com/file/d/1lakZC14WrsOBHQ0b6eCz1opNDWKD_Dpv/view?usp=drive_link"
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1lakZC14WrsOBHQ0b6eCz1opNDWKD_Dpv
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1lakZC14WrsOBHQ0b6eCz1opNDWKD_Dpv/view?usp=drive_link
# To: /content/view?usp=drive_link
# 8.92kB [00:00, 21.3MB/s]

# %%
Image("/content/runs/detect/train/train_batch0.jpg",width=600)

# %%
Image("/content/runs/detect/train/train_batch521.jpg",width=600)

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/lumpy-skin-diesease--1/valid/labels.cache... 68 images, 0 backgrounds, 0 corrupt: 100% 68/68 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:02<00:00,  1.84it/s]
#                    all         68        104      0.931      0.649      0.719      0.539
# Speed: 7.9ms preprocess, 10.3ms inference, 0.0ms loss, 5.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/68 /content/lumpy-skin-diesease--1/test/images/555555_png.rf.98fb9048b57b24f65c5f9636dcc8ab3f.jpg: 640x640 1 lumpy skin diesease, 11.6ms
# image 2/68 /content/lumpy-skin-diesease--1/test/images/Screenshot__-_-_-_-_-_-_-_-_-_-_-_-_-_-_png.rf.1a732104d66dfcca13e42d799bca416e.jpg: 640x640 1 lumpy skin diesease, 9.2ms
# image 3/68 /content/lumpy-skin-diesease--1/test/images/Screenshot__-_-_-_-_-_-_-_-_-_-_-_-_-_-_png.rf.1a95234e19cc9f6e42d5c18109cdd19c.jpg: 640x640 1 lumpy skin diesease, 8.5ms
# image 4/68 /content/lumpy-skin-diesease--1/test/images/Screenshot__-_-_-_-_-_-_-_-_-_-_-_-_-_-_png.rf.3e2a931c3aee9eb1f94dd9121dd44923.jpg: 640x640 1 lumpy skin diesease, 8.2ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
Image("/content/runs/detect/predict/555555_png.rf.98fb9048b57b24f65c5f9636dcc8ab3f.jpg",width=600)

# %%
Image("/content/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train/PR_curve.png", width=600)
